# %%
caminho_dados = '/content/drive/MyDrive/Asimov_CursoPythonPandas/2023_Viagem.csv'

# %%
import pandas as pd

# %%
df_viagens = pd.read_csv(caminho_dados, encoding= 'Windows-1252', sep=';', decimal=",")

# %%
df_viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826989 entries, 0 to 826988
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  826989 non-null  int64
#  1   Número da Proposta (PCDP)            826989 non-null  object
#  2   Situação                             826989 non-null  object
#  3   Viagem Urgente                       826989 non-null  object
#  4   Justificativa Urgência Viagem        826887 non-null  object
#  5   Código do órgão superior             826989 non-null  int64
#  6   Nome do órgão superior               826989 non-null  object
#  7   Código órgão solicitante             826989 non-null  int64
#  8   Nome órgão solicitante               826989 non-null  object
#  9   CPF viajante                         748302 non-null  object
#  10  Nome                                 826989 non-null  object
#  11  Cargo                                505154 non-null  object
#  12  Função                               826989 non-null  object
#  13  Descrição Função                     826977 non-null  object
#  14  Período - Data de início             826989 non-null  object
#  15  Período - Data de fim                826989 non-null  object
#  16  Destinos                             826989 non-null  object
#  17  Motivo                               826989 non-null  object
#  18  Valor diárias                        826989 non-null  float64
#  19  Valor passagens                      826989 non-null  float64
#  20  Valor devolução                      826989 non-null  float64
#  21  Valor outros gastos                  826989 non-null  float64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 138.8+ MB

# %%
pd.set_option('display.max_columns', None)

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                                    NaN  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                                    NaN  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    01/01/2023            02/12/2023
# 1                    16/01/2023            28/02/2024
# 2                    10/01/2023            29/01/2023
# 3                    05/02/2023            10/02/2023
# 4                    01/01/2023            07/07/2023
# ...                         ...                   ...
# 826984               05/12/2023            06/12/2023
# 826985               11/12/2023            13/12/2023
# 826986               07/12/2023            08/12/2023
# 826987               11/12/2023            11/12/2023
# 826988               15/12/2023            18/12/2023
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos
# 0                  0.00              0.0                 0.00
# 1                  0.00              0.0                 0.00
# 2               7434.13              0.0              1095.35
# 3                  0.00              0.0                 0.00
# 4              14903.10              0.0                 0.00
# ...                 ...              ...                  ...
# 826984          3331.29              0.0                 0.00
# 826985          1837.18              0.0                 0.00
# 826986          4555.95              0.0                 0.00
# 826987          3745.53              0.0               400.00
# 826988          2961.55              0.0                 0.00
#
# [826989 rows x 22 columns]

# %%
df_viagens['Nome do órgão superior']
# Out:
# 0         Ministério da Educação
# 1         Ministério da Educação
# 2           Ministério da Defesa
# 3         Ministério da Educação
# 4           Ministério da Defesa
#                    ...
# 826984            Sem informação
# 826985            Sem informação
# 826986            Sem informação
# 826987            Sem informação
# 826988            Sem informação
# Name: Nome do órgão superior, Length: 826989, dtype: object

# %%
df_viagens["Valor diárias"]
# Out:
# 0             0.00
# 1             0.00
# 2         39565.70
# 3          1013.96
# 4             0.00
#             ...
# 826984      606.89
# 826985     1089.00
# 826986      734.13
# 826987      319.28
# 826988        0.00
# Name: Valor diárias, Length: 826989, dtype: float64

# %%
colunas = ["Nome do órgão superior", "Valor diárias"]

# %%
df_viagens[colunas]
# Out:
#         Nome do órgão superior  Valor diárias
# 0       Ministério da Educação           0.00
# 1       Ministério da Educação           0.00
# 2         Ministério da Defesa       39565.70
# 3       Ministério da Educação        1013.96
# 4         Ministério da Defesa           0.00
# ...                        ...            ...
# 826984          Sem informação         606.89
# 826985          Sem informação        1089.00
# 826986          Sem informação         734.13
# 826987          Sem informação         319.28
# 826988          Sem informação           0.00
#
# [826989 rows x 2 columns]

# %%
df_viagens['Nome do órgão superior'].str.upper().str.replace("MINISTÉRIO", "MIN.")
# Out:
# 0         MIN. DA EDUCAÇÃO
# 1         MIN. DA EDUCAÇÃO
# 2           MIN. DA DEFESA
# 3         MIN. DA EDUCAÇÃO
# 4           MIN. DA DEFESA
#                 ...
# 826984      SEM INFORMAÇÃO
# 826985      SEM INFORMAÇÃO
# 826986      SEM INFORMAÇÃO
# 826987      SEM INFORMAÇÃO
# 826988      SEM INFORMAÇÃO
# Name: Nome do órgão superior, Length: 826989, dtype: object

# %%
df_viagens[["Valor diárias", "Valor passagens"]]
# Out:
#         Valor diárias  Valor passagens
# 0                0.00             0.00
# 1                0.00             0.00
# 2            39565.70          7434.13
# 3             1013.96             0.00
# 4                0.00         14903.10
# ...               ...              ...
# 826984         606.89          3331.29
# 826985        1089.00          1837.18
# 826986         734.13          4555.95
# 826987         319.28          3745.53
# 826988           0.00          2961.55
#
# [826989 rows x 2 columns]

# %%
df_viagens["Valor diárias"] + df_viagens["Valor passagens"]
# Out:
# 0             0.00
# 1             0.00
# 2         46999.83
# 3          1013.96
# 4         14903.10
#             ...
# 826984     3938.18
# 826985     2926.18
# 826986     5290.08
# 826987     4064.81
# 826988     2961.55
# Length: 826989, dtype: float64

# %%
df_viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826989 entries, 0 to 826988
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  826989 non-null  int64
#  1   Número da Proposta (PCDP)            826989 non-null  object
#  2   Situação                             826989 non-null  object
#  3   Viagem Urgente                       826989 non-null  object
#  4   Justificativa Urgência Viagem        826887 non-null  object
#  5   Código do órgão superior             826989 non-null  int64
#  6   Nome do órgão superior               826989 non-null  object
#  7   Código órgão solicitante             826989 non-null  int64
#  8   Nome órgão solicitante               826989 non-null  object
#  9   CPF viajante                         748302 non-null  object
#  10  Nome                                 826989 non-null  object
#  11  Cargo                                505154 non-null  object
#  12  Função                               826989 non-null  object
#  13  Descrição Função                     826977 non-null  object
#  14  Período - Data de início             826989 non-null  object
#  15  Período - Data de fim                826989 non-null  object
#  16  Destinos                             826989 non-null  object
#  17  Motivo                               826989 non-null  object
#  18  Valor diárias                        826989 non-null  float64
#  19  Valor passagens                      826989 non-null  float64
#  20  Valor devolução                      826989 non-null  float64
#  21  Valor outros gastos                  826989 non-null  float64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 138.8+ MB

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                                    NaN  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                                    NaN  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    01/01/2023            02/12/2023
# 1                    16/01/2023            28/02/2024
# 2                    10/01/2023            29/01/2023
# 3                    05/02/2023            10/02/2023
# 4                    01/01/2023            07/07/2023
# ...                         ...                   ...
# 826984               05/12/2023            06/12/2023
# 826985               11/12/2023            13/12/2023
# 826986               07/12/2023            08/12/2023
# 826987               11/12/2023            11/12/2023
# 826988               15/12/2023            18/12/2023
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos
# 0                  0.00              0.0                 0.00
# 1                  0.00              0.0                 0.00
# 2               7434.13              0.0              1095.35
# 3                  0.00              0.0                 0.00
# 4              14903.10              0.0                 0.00
# ...                 ...              ...                  ...
# 826984          3331.29              0.0                 0.00
# 826985          1837.18              0.0                 0.00
# 826986          4555.95              0.0                 0.00
# 826987          3745.53              0.0               400.00
# 826988          2961.55              0.0                 0.00
#
# [826989 rows x 22 columns]

# %%
df_viagens['Valor diárias']
# Out:
# 0             0.00
# 1             0.00
# 2         39565.70
# 3          1013.96
# 4             0.00
#             ...
# 826984      606.89
# 826985     1089.00
# 826986      734.13
# 826987      319.28
# 826988        0.00
# Name: Valor diárias, Length: 826989, dtype: float64

# %%
#df_viagens['Valor passagens'] = df_viagens['Valor passagens'].str.replace(',','.').astype(float)
#df_viagens['Valor devolução'] = df_viagens['Valor devolução'].str.replace(',','.').astype(float)
#df_viagens['Valor outros gastos'] = df_viagens['Valor outros gastos'].str.replace(',','.').astype(float)

# %%
df_viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826989 entries, 0 to 826988
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  826989 non-null  int64
#  1   Número da Proposta (PCDP)            826989 non-null  object
#  2   Situação                             826989 non-null  object
#  3   Viagem Urgente                       826989 non-null  object
#  4   Justificativa Urgência Viagem        826887 non-null  object
#  5   Código do órgão superior             826989 non-null  int64
#  6   Nome do órgão superior               826989 non-null  object
#  7   Código órgão solicitante             826989 non-null  int64
#  8   Nome órgão solicitante               826989 non-null  object
#  9   CPF viajante                         748302 non-null  object
#  10  Nome                                 826989 non-null  object
#  11  Cargo                                505154 non-null  object
#  12  Função                               826989 non-null  object
#  13  Descrição Função                     826977 non-null  object
#  14  Período - Data de início             826989 non-null  object
#  15  Período - Data de fim                826989 non-null  object
#  16  Destinos                             826989 non-null  object
#  17  Motivo                               826989 non-null  object
#  18  Valor diárias                        826989 non-null  float64
#  19  Valor passagens                      826989 non-null  float64
#  20  Valor devolução                      826989 non-null  float64
#  21  Valor outros gastos                  826989 non-null  float64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 138.8+ MB

# %%
df_viagens["Valor diárias"] + df_viagens["Valor passagens"]
# Out:
# 0             0.00
# 1             0.00
# 2         46999.83
# 3          1013.96
# 4         14903.10
#             ...
# 826984     3938.18
# 826985     2926.18
# 826986     5290.08
# 826987     4064.81
# 826988     2961.55
# Length: 826989, dtype: float64

# %%
df_viagens['Despesas'] = df_viagens['Valor diárias'] + df_viagens['Valor passagens'] + df_viagens['Valor outros gastos']

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                                    NaN  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                                    NaN  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    01/01/2023            02/12/2023
# 1                    16/01/2023            28/02/2024
# 2                    10/01/2023            29/01/2023
# 3                    05/02/2023            10/02/2023
# 4                    01/01/2023            07/07/2023
# ...                         ...                   ...
# 826984               05/12/2023            06/12/2023
# 826985               11/12/2023            13/12/2023
# 826986               07/12/2023            08/12/2023
# 826987               11/12/2023            11/12/2023
# 826988               15/12/2023            18/12/2023
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  Despesas
# 0                  0.00              0.0                 0.00      0.00
# 1                  0.00              0.0                 0.00      0.00
# 2               7434.13              0.0              1095.35  48095.18
# 3                  0.00              0.0                 0.00   1013.96
# 4              14903.10              0.0                 0.00  14903.10
# ...                 ...              ...                  ...       ...
# 826984          3331.29              0.0                 0.00   3938.18
# 826985          1837.18              0.0                 0.00   2926.18
# 826986          4555.95              0.0                 0.00   5290.08
# 826987          3745.53              0.0               400.00   4464.81
# 826988          2961.55              0.0                 0.00   2961.55
#
# [826989 rows x 23 columns]

# %%
(df_viagens['Cargo'].value_counts(normalize=True) * 100).rename('Proporção de viagens').reset_index()
# Out:
#                                         Cargo  Proporção de viagens
# 0           Informações protegidas por sigilo             23.403160
# 1            PROFESSOR DO MAGISTERIO SUPERIOR             10.802646
# 2       PROFESSOR ENS BASICO TECN TECNOLOGICO              7.418728
# 3                 CONTRATADO LEI 8745/93 - NI              3.521104
# 4         AUDITOR FISCAL FEDERAL AGROPECUARIO              3.282563
# ..                                        ...                   ...
# 816                              FISICO - 40H              0.000198
# 817          PROFISSIONAL TECNICO SUPERIOR II              0.000198
# 818  ARTIFICE DE ESTRUTURA DE OBRAS E METALUR              0.000198
# 819     DELEGADO DE POLICIA - PRIMEIRA CLASSE              0.000198
# 820           ESPEC EM CIENCIA DE DADOS - 40H              0.000198
#
# [821 rows x 2 columns]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

df_viagens.groupby('Cargo')['Despesas'].sum().reset_index().sort_values(by='Despesas', ascending=False)
# Out:
#                                         Cargo     Despesas
# 443         Informações protegidas por sigilo 370919369.30
# 568          PROFESSOR DO MAGISTERIO SUPERIOR 110890764.22
# 569     PROFESSOR ENS BASICO TECN TECNOLOGICO  52548741.25
# 685                  TECNICO DO SEGURO SOCIAL  45881679.92
# 72                         ANALISTA AMBIENTAL  35344371.79
# ..                                        ...          ...
# 454                                   LOCUTOR         0.00
# 152  ASG - OPERADOR DE MAQUINA E EQUIPAMENTOS         0.00
# 723                       TECNICO EM GEOLOGIA         0.00
# 301                               CENOTECNICO         0.00
# 733                     TECNICO EM METALURGIA         0.00
#
# [821 rows x 2 columns]

# %%
viagens_por_cargo = (df_viagens['Cargo'].value_counts(normalize=True) * 100).rename('Proporção de viagens').reset_index()

# %%
filtro_mais_de_1_pct = viagens_por_cargo['Proporção de viagens'] > 1

# %%
viagens_por_cargo[filtro_mais_de_1_pct]
# Out:
#                                        Cargo  Proporção de viagens
# 0          Informações protegidas por sigilo                 23.40
# 1           PROFESSOR DO MAGISTERIO SUPERIOR                 10.80
# 2      PROFESSOR ENS BASICO TECN TECNOLOGICO                  7.42
# 3                CONTRATADO LEI 8745/93 - NI                  3.52
# 4        AUDITOR FISCAL FEDERAL AGROPECUARIO                  3.28
# 5                         ANALISTA AMBIENTAL                  2.69
# 6                ASSISTENTE EM ADMINISTRAçãO                  2.31
# 7    TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  2.15
# 8                   TECNICO DO SEGURO SOCIAL                  2.11
# 9   AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL                  2.00
# 10    ANALISTA TRIBUTARIO REC FEDERAL BRASIL                  1.69
# 11                AUDITOR FISCAL DO TRABALHO                  1.54
# 12                                 MOTORISTA                  1.51
# 13                 ANALISTA DO SEGURO SOCIAL                  1.27
# 14                         TECNICO AMBIENTAL                  1.18
# 15                     AGENTE ADMINISTRATIVO                  1.00

# %%
filtro_e_tecnico = viagens_por_cargo['Cargo'].str.startswith('TECNICO')

# %%
viagens_por_cargo[filtro_e_tecnico]
# Out:
#                                        Cargo  Proporção de viagens
# 7    TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  2.15
# 8                   TECNICO DO SEGURO SOCIAL                  2.11
# 14                         TECNICO AMBIENTAL                  1.18
# 18                    TECNICO ADMINISTRATIVO                  0.87
# 23          TECNICO EM ASSUNTOS EDUCACIONAIS                  0.57
# ..                                       ...                   ...
# 801                TECNICO EM HIGIENE DENTAL                  0.00
# 803                         TECNICO EDUCACAO                  0.00
# 806                  TECNICO DE ENFERMAGEM I                  0.00
# 809  TECNICO EM PRESERVACAO ARQUITETONICA II                  0.00
# 814               TECNICO DE PROCESSAMENTO I                  0.00
#
# [142 rows x 2 columns]

# %%
viagens_por_cargo[filtro_e_tecnico | filtro_mais_de_1_pct]
# Out:
#                                        Cargo  Proporção de viagens
# 0          Informações protegidas por sigilo                 23.40
# 1           PROFESSOR DO MAGISTERIO SUPERIOR                 10.80
# 2      PROFESSOR ENS BASICO TECN TECNOLOGICO                  7.42
# 3                CONTRATADO LEI 8745/93 - NI                  3.52
# 4        AUDITOR FISCAL FEDERAL AGROPECUARIO                  3.28
# ..                                       ...                   ...
# 801                TECNICO EM HIGIENE DENTAL                  0.00
# 803                         TECNICO EDUCACAO                  0.00
# 806                  TECNICO DE ENFERMAGEM I                  0.00
# 809  TECNICO EM PRESERVACAO ARQUITETONICA II                  0.00
# 814               TECNICO DE PROCESSAMENTO I                  0.00
#
# [155 rows x 2 columns]

# %%
gastos_medio_cargo = df_viagens.groupby('Cargo')['Despesas'].mean().reset_index()

# %%
gastos_medio_cargo[gastos_medio_cargo['Despesas'] > 10_000]
# Out:
#                                        Cargo  Despesas
# 3       AAD-AUXILIAR DE RECURSOS FINANCEIROS  15545.94
# 37          AGENTE DE SERVICOS COMPLEMETARES  13975.38
# 170                ASSISTENTE DE CHANCELARIA  10356.99
# 230                AUXILIAR DE CONTABILIDADE  14015.48
# 257            AUXILIAR DE SERVICOS DIVERSOS  19000.96
# 268            AUXILIAR NM - 06 (DEC JUD-ME)  12323.94
# 305                              CONSELHEIRO  12271.56
# 325    DELEGADO DE POLICIA - PRIMEIRA CLASSE  34105.32
# 389  ESP EM REGULACAO E VIGILANCIA SANITARIA  13013.60
# 402        ESPECIALISTA EM ATIV HOSPITALARES  12686.31
# 471              MEDICO PROGRAMA MAIS MEDICO  11367.61
# 480              MINISTRO DE PRIMEIRA CLASSE  19072.66
# 481               MINISTRO DE SEGUNDA CLASSE  14458.99
# 498                   OFICIAL DE CHANCELARIA  11375.51
# 524   PAPILOSCOPISTA POLICIAL-SEGUNDA CLASSE  15421.69
# 551                        PRIMEIRO SARGENTO  17509.58
# 552                      PRIMEIRO SECRETARIO  14036.74
# 553                         PRIMEIRO TENENTE  12642.73
# 558                       PRODUTOR EXECUTIVO  10410.95
# 579                PROFISSIONAL ARTES SENICA  11642.59
# 614                       SEGUNDO SECRETARIO  12103.76
# 615                          SEGUNDO TENENTE  40372.27
# 616                          SEGUNDO-TENENTE  19820.29
# 656                       TECNICO DE ARQUIVO  10170.50
# 779             TECNICO NM - 21 (DEC JUD-ME)  11696.64
# 780             TECNICO NM - 22 (DEC JUD-ME)  13720.12
# 800                        TERCEIRO SARGENTO  19032.81
# 801                      TERCEIRO SECRETARIO  11833.21

# %%
#df_viagens.dropna(subset='Cargo') para excluir as linhas sem informação
df_viagens.fillna("NÃO IDENTIFICADO") # para preencher as linhas sem informação
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#             CPF viajante                             Nome  \
# 0         ***.875.238-**           PRISCILA LEAL DA SILVA
# 1       NÃO IDENTIFICADO          CAMILLA DUARTE DA SILVA
# 2         ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3         ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4         ***.855.388-**                    GREGOR GASPAR
# ...                  ...                              ...
# 826984    ***.748.269-**               BIANCA VIANA KIVEL
# 826985    ***.231.806-**               LUCAS ALVES FREIRE
# 826986    ***.632.011-**                   SERGIO BOTELHO
# 826987    ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988    ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                       NÃO IDENTIFICADO  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                       NÃO IDENTIFICADO  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    01/01/2023            02/12/2023
# 1                    16/01/2023            28/02/2024
# 2                    10/01/2023            29/01/2023
# 3                    05/02/2023            10/02/2023
# 4                    01/01/2023            07/07/2023
# ...                         ...                   ...
# 826984               05/12/2023            06/12/2023
# 826985               11/12/2023            13/12/2023
# 826986               07/12/2023            08/12/2023
# 826987               11/12/2023            11/12/2023
# 826988               15/12/2023            18/12/2023
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  Despesas
# 0                  0.00             0.00                 0.00      0.00
# 1                  0.00             0.00                 0.00      0.00
# 2               7434.13             0.00              1095.35  48095.18
# 3                  0.00             0.00                 0.00   1013.96
# 4              14903.10             0.00                 0.00  14903.10
# ...                 ...              ...                  ...       ...
# 826984          3331.29             0.00                 0.00   3938.18
# 826985          1837.18             0.00                 0.00   2926.18
# 826986          4555.95             0.00                 0.00   5290.08
# 826987          3745.53             0.00               400.00   4464.81
# 826988          2961.55             0.00                 0.00   2961.55
#
# [826989 rows x 23 columns]

# %%
df_viagens['Cargo'] = df_viagens['Cargo'].fillna("NÃO IDENTIFICADO")

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                       NÃO IDENTIFICADO  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                       NÃO IDENTIFICADO  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    01/01/2023            02/12/2023
# 1                    16/01/2023            28/02/2024
# 2                    10/01/2023            29/01/2023
# 3                    05/02/2023            10/02/2023
# 4                    01/01/2023            07/07/2023
# ...                         ...                   ...
# 826984               05/12/2023            06/12/2023
# 826985               11/12/2023            13/12/2023
# 826986               07/12/2023            08/12/2023
# 826987               11/12/2023            11/12/2023
# 826988               15/12/2023            18/12/2023
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  Despesas
# 0                  0.00             0.00                 0.00      0.00
# 1                  0.00             0.00                 0.00      0.00
# 2               7434.13             0.00              1095.35  48095.18
# 3                  0.00             0.00                 0.00   1013.96
# 4              14903.10             0.00                 0.00  14903.10
# ...                 ...              ...                  ...       ...
# 826984          3331.29             0.00                 0.00   3938.18
# 826985          1837.18             0.00                 0.00   2926.18
# 826986          4555.95             0.00                 0.00   5290.08
# 826987          3745.53             0.00               400.00   4464.81
# 826988          2961.55             0.00                 0.00   2961.55
#
# [826989 rows x 23 columns]

# %%
pd.to_datetime(df_viagens['Período - Data de início'], format="%d/%m/%Y")
# Out:
# 0        2023-01-01
# 1        2023-01-16
# 2        2023-01-10
# 3        2023-02-05
# 4        2023-01-01
#             ...
# 826984   2023-12-05
# 826985   2023-12-11
# 826986   2023-12-07
# 826987   2023-12-11
# 826988   2023-12-15
# Name: Período - Data de início, Length: 826989, dtype: datetime64[ns]

# %%
df_viagens['Período - Data de início'] = pd.to_datetime(df_viagens['Período - Data de início'], format="%d/%m/%Y")
df_viagens['Período - Data de fim'] = pd.to_datetime(df_viagens['Período - Data de fim'], format="%d/%m/%Y")

# %%
df_viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826989 entries, 0 to 826988
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  826989 non-null  int64
#  1   Número da Proposta (PCDP)            826989 non-null  object
#  2   Situação                             826989 non-null  object
#  3   Viagem Urgente                       826989 non-null  object
#  4   Justificativa Urgência Viagem        826887 non-null  object
#  5   Código do órgão superior             826989 non-null  int64
#  6   Nome do órgão superior               826989 non-null  object
#  7   Código órgão solicitante             826989 non-null  int64
#  8   Nome órgão solicitante               826989 non-null  object
#  9   CPF viajante                         748302 non-null  object
#  10  Nome                                 826989 non-null  object
#  11  Cargo                                826989 non-null  object
#  12  Função                               826989 non-null  object
#  13  Descrição Função                     826977 non-null  object
#  14  Período - Data de início             826989 non-null  datetime64[ns]
#  15  Período - Data de fim                826989 non-null  datetime64[ns]
#  16  Destinos                             826989 non-null  object
#  17  Motivo                               826989 non-null  object
#  18  Valor diárias                        826989 non-null  float64
#  19  Valor passagens                      826989 non-null  float64
#  20  Valor devolução                      826989 non-null  float64
#  21  Valor outros gastos                  826989 non-null  float64
#  22  Despesas                             826989 non-null  float64
# dtypes: datetime64[ns](2), float64(5), int64(3), object(13)
# memory usage: 145.1+ MB

# %%
df_viagens['Mes da viagem'] = df_viagens['Período - Data de início'].dt.month_name()

# %%
(df_viagens['Período - Data de fim'] - df_viagens['Período - Data de início']).dt.days
# Out:
# 0         335
# 1         408
# 2          19
# 3           5
# 4         187
#          ...
# 826984      1
# 826985      2
# 826986      1
# 826987      0
# 826988      3
# Length: 826989, dtype: int64

# %%
df_viagens['Dias de viagem'] = (df_viagens['Período - Data de fim'] - df_viagens['Período - Data de início']).dt.days

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                       NÃO IDENTIFICADO  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                       NÃO IDENTIFICADO  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    2023-01-01            2023-12-02
# 1                    2023-01-16            2024-02-28
# 2                    2023-01-10            2023-01-29
# 3                    2023-02-05            2023-02-10
# 4                    2023-01-01            2023-07-07
# ...                         ...                   ...
# 826984               2023-12-05            2023-12-06
# 826985               2023-12-11            2023-12-13
# 826986               2023-12-07            2023-12-08
# 826987               2023-12-11            2023-12-11
# 826988               2023-12-15            2023-12-18
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  Despesas  \
# 0                  0.00             0.00                 0.00      0.00
# 1                  0.00             0.00                 0.00      0.00
# 2               7434.13             0.00              1095.35  48095.18
# 3                  0.00             0.00                 0.00   1013.96
# 4              14903.10             0.00                 0.00  14903.10
# ...                 ...              ...                  ...       ...
# 826984          3331.29             0.00                 0.00   3938.18
# 826985          1837.18             0.00                 0.00   2926.18
# 826986          4555.95             0.00                 0.00   5290.08
# 826987          3745.53             0.00               400.00   4464.81
# 826988          2961.55             0.00                 0.00   2961.55
#
#        Mes da viagem  Dias de viagem
# 0            January             335
# 1            January             408
# 2            January              19
# 3           February               5
# 4            January             187
# ...              ...             ...
# 826984      December               1
# 826985      December               2
# 826986      December               1
# 826987      December               0
# 826988      December               3
#
# [826989 rows x 25 columns]

# %%
(df_viagens
.groupby('Cargo')
.agg(
    despesa_media=('Despesas', 'mean'),
    duracao_media=('Dias de viagem', 'mean'),
    despesas_totais=('Despesas', 'sum'),
    destino_mais_frequente=('Destinos', pd.Series.mode),
    n_viagens=('Nome', 'count')
    )
.reset_index()
)
# Out:
#                                     Cargo  despesa_media  duracao_media  \
# 0           AAD-AUX DE RECURSOS MATERIAIS        3592.10           9.40
# 1             AAD-AUXILIAR ADMINISTRATIVO         115.76           0.00
# 2               AAD-AUXILIAR DE OPERACOES        7973.39          16.71
# 3    AAD-AUXILIAR DE RECURSOS FINANCEIROS       15545.94           5.50
# 4         AAD-OPERADOR DE MICROCOMPUTADOR        1186.47           4.00
# ..                                    ...            ...            ...
# 817          VICE-PRESIDENTE DA REPUBLICA        7068.20           1.50
# 818                              VIDREIRO           0.00           6.00
# 819                             VIGILANTE         693.31           1.79
# 820                   VISITADOR SANITARIO        1402.57           3.88
# 821                           ZOOTECNISTA         655.56           1.87
#
#      despesas_totais             destino_mais_frequente  n_viagens
# 0           17960.50                   Foz do Iguaçu/PR          5
# 1            1620.65                        Alcantil/PB         14
# 2           55813.76                        Brasília/DF          7
# 3           31091.89  [Paris/França, Rio de Janeiro/RJ]          2
# 4            1186.47                       Petrolina/PE          1
# ..               ...                                ...        ...
# 817         14136.40   [Lisboa/Portugal, Quito/Equador]          2
# 818             0.00                        Brasília/DF          1
# 819        739763.32                       Três Rios/RJ       1067
# 820         58907.74                   Guajará-Mirim/RO         42
# 821         74734.27                        Brasília/DF        114
#
# [822 rows x 6 columns]

# %%
df_cargos = df_viagens['Cargo'].value_counts(normalize=True).reset_index()

# %%
df_cargos
# Out:
#                                       Cargo  proportion
# 0                          NÃO IDENTIFICADO        0.39
# 1         Informações protegidas por sigilo        0.14
# 2          PROFESSOR DO MAGISTERIO SUPERIOR        0.07
# 3     PROFESSOR ENS BASICO TECN TECNOLOGICO        0.05
# 4               CONTRATADO LEI 8745/93 - NI        0.02
# ..                                      ...         ...
# 817  PAPILOSCOPISTA POLICIAL-SEGUNDA CLASSE        0.00
# 818                           AGENTE SOCIAL        0.00
# 819               PROFISSIONAL ARTES CENICA        0.00
# 820                ANALISTA DE SISTEMAS III        0.00
# 821              ASSISTENTE DE SECRETARIA I        0.00
#
# [822 rows x 2 columns]

# %%
df_cargos.loc[df_cargos['proportion'] > 0.01, 'Cargo']
# Out:
# 0                             NÃO IDENTIFICADO
# 1            Informações protegidas por sigilo
# 2             PROFESSOR DO MAGISTERIO SUPERIOR
# 3        PROFESSOR ENS BASICO TECN TECNOLOGICO
# 4                  CONTRATADO LEI 8745/93 - NI
# 5          AUDITOR FISCAL FEDERAL AGROPECUARIO
# 6                           ANALISTA AMBIENTAL
# 7                  ASSISTENTE EM ADMINISTRAçãO
# 8      TECNICO INFOR GEOGRAFICAS E ESTATISTICA
# 9                     TECNICO DO SEGURO SOCIAL
# 10    AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL
# 11      ANALISTA TRIBUTARIO REC FEDERAL BRASIL
# Name: Cargo, dtype: object

# %%
df_viagens_consolidado = (
  df_viagens
  .groupby('Cargo')
  .agg(
      despesa_media=('Despesas', 'mean'),
      duracao_media=('Dias de viagem', 'mean'),
      despesas_totais=('Despesas', 'sum'),
      destino_mais_frequente=('Destinos', pd.Series.mode),
      n_viagens=('Nome', 'count')
      )
  .reset_index()
)

# %%
cargos_relevantes = df_cargos.loc[df_cargos['proportion'] > 0.01, 'Cargo']

# %%
filtro = df_viagens_consolidado['Cargo'].isin(cargos_relevantes)

# %%
df_final = df_viagens_consolidado[filtro].sort_values(by='n_viagens', ascending=False)

# %%
df_final.plot(x='Cargo', y='n_viagens', kind='bar')
# Out:
# <Axes: xlabel='Cargo'>

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.barh(df_final['Cargo'], df_final['n_viagens'], color='#49deac')
ax.invert_yaxis()
ax.set_facecolor('#3b3b47')

fig.suptitle('Viagens por cargo público (2023)')

plt.figtext(0.65, 0.89,'Fonte: Portal da Transparência', fontsize=8)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize=8)
plt.xlabel('Número de viagens')

plt.show()

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                       NÃO IDENTIFICADO  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                       NÃO IDENTIFICADO  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    2023-01-01            2023-12-02
# 1                    2023-01-16            2024-02-28
# 2                    2023-01-10            2023-01-29
# 3                    2023-02-05            2023-02-10
# 4                    2023-01-01            2023-07-07
# ...                         ...                   ...
# 826984               2023-12-05            2023-12-06
# 826985               2023-12-11            2023-12-13
# 826986               2023-12-07            2023-12-08
# 826987               2023-12-11            2023-12-11
# 826988               2023-12-15            2023-12-18
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  Despesas  \
# 0                  0.00             0.00                 0.00      0.00
# 1                  0.00             0.00                 0.00      0.00
# 2               7434.13             0.00              1095.35  48095.18
# 3                  0.00             0.00                 0.00   1013.96
# 4              14903.10             0.00                 0.00  14903.10
# ...                 ...              ...                  ...       ...
# 826984          3331.29             0.00                 0.00   3938.18
# 826985          1837.18             0.00                 0.00   2926.18
# 826986          4555.95             0.00                 0.00   5290.08
# 826987          3745.53             0.00               400.00   4464.81
# 826988          2961.55             0.00                 0.00   2961.55
#
#        Mes da viagem  Dias de viagem
# 0            January             335
# 1            January             408
# 2            January              19
# 3           February               5
# 4            January             187
# ...              ...             ...
# 826984      December               1
# 826985      December               2
# 826986      December               1
# 826987      December               0
# 826988      December               3
#
# [826989 rows x 25 columns]

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.scatter(df_viagens['Dias de viagem'], df_viagens['Despesas'], alpha=0.2)
# ax.set_xlim(0, 100)
# ax.set_ylim(0, 25_000)

# %%
(df_viagens['Despesas'] > 175_000).value_counts()
# Out:
# Despesas
# False    826985
# True          4
# Name: count, dtype: int64

# %%
filtro = df_viagens['Despesas'] > 175_000

# %%
df_viagens[filtro]
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 129008                             18782567              000277/23-5C
# 129058                             18782625              000289/23-5C
# 206998                             18877982             Informações p
# 466711                             19194886                 004304/23
#
#          Situação Viagem Urgente  \
# 129008  Realizada            SIM
# 129058  Realizada            SIM
# 206998  Realizada            NÃO
# 466711  Realizada            SIM
#
#                             Justificativa Urgência Viagem  \
# 129008  A autorização de afastamento foi publicada hoj...
# 129058  Devido ao cancelamento da Visita Oficial do PR...
# 206998  Informação protegida por sigilo nos termos da ...
# 466711  Mudança de itinerário devido à situação na Fai...
#
#         Código do órgão superior                     Nome do órgão superior  \
# 129008                     20000                   Presidência da República
# 129058                     20000                   Presidência da República
# 206998                     30000  Ministério da Justiça e Segurança Pública
# 466711                     35000         Ministério das Relações Exteriores
#
#         Código órgão solicitante  \
# 129008                     20000
# 129058                     20000
# 206998                     30108
# 466711                     35000
#
#                                    Nome órgão solicitante    CPF viajante  \
# 129008  Presidência da República - Unidades com víncul...  ***.739.980-**
# 129058  Presidência da República - Unidades com víncul...  ***.919.570-**
# 206998                                    Polícia Federal     ID006200249
# 466711  Ministério das Relações Exteriores - Unidades ...  ***.501.297-**
#
#                                      Nome                              Cargo  \
# 129008           LEANDRO AUGUSTO ANDERSON                   NÃO IDENTIFICADO
# 129058       LUIS CARLOS MACHADO DA SILVA                   NÃO IDENTIFICADO
# 206998  Informações protegidas por sigilo  Informações protegidas por sigilo
# 466711           MAURO LUIZ IECKER VIEIRA        MINISTRO DE PRIMEIRA CLASSE
#
#           Função                   Descrição Função Período - Data de início  \
# 129008  CCX-0207                           CCX-0207               2023-03-26
# 129058  CCX-0207                           CCX-0207               2023-03-26
# 206998       -11  Informações protegidas por sigilo               2023-06-18
# 466711  CNE-0001         Cargo de Natureza Especial               2023-10-06
#
#        Período - Data de fim  \
# 129008            2023-08-04
# 129058            2023-08-06
# 206998            2024-01-20
# 466711            2023-10-15
#
#                                                  Destinos  \
# 129008                         Xangai/China, São Paulo/SP
# 129058                         Xangai/China, São Paulo/SP
# 206998                  Informações protegidas por sigilo
# 466711  Jacarta/Indonésia, Phnom Penh/Camboja, Nova Yo...
#
#                                                    Motivo  Valor diárias  \
# 129008  Conforme o previsto no Decreto nº 6.381 de 27 ...      174812.69
# 129058  Conforme o previsto no Decreto nº 6.381 de 27 ...      175337.40
# 206998  Informação protegida por sigilo nos termos da ...      160692.47
# 466711     Visitas oficiais a países do Sudeste Asiático.        8468.86
#
#         Valor passagens  Valor devolução  Valor outros gastos  Despesas  \
# 129008         11610.06             0.00              5625.81 192048.56
# 129058         11757.14             0.00              5581.48 192676.02
# 206998         14583.60             0.00              9511.35 184787.42
# 466711        186723.29             0.00                 0.00 195192.15
#
#        Mes da viagem  Dias de viagem
# 129008         March             131
# 129058         March             133
# 206998          June             216
# 466711       October               9

# %%
caminho_dados_passagens = caminho_dados = '/content/drive/MyDrive/Asimov_CursoPythonPandas/2023_Passagem.csv'

# %%
df_passagens = pd.read_csv(caminho_dados_passagens, encoding='Windows-1252', sep=';', decimal=',')

# %%
df_passagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18288418              000007/23-1C
# 1                                  18302983                 000001/23
# 2                                  18306758                 000002/23
# 3                                  18306785                 000004/23
# 4                                  18306786                 000003/23
# ...                                     ...                       ...
# 387668                           2023001628             Sem informaçã
# 387669                           2023001628             Sem informaçã
# 387670                           2023001631             Sem informaçã
# 387671                           2023001631             Sem informaçã
# 387672                           2023001651             Sem informaçã
#
#        Meio de transporte País - Origem ida   UF - Origem ida  \
# 0                   Aéreo            Brasil  Distrito Federal
# 1                   Aéreo            Brasil         São Paulo
# 2                   Aéreo            Brasil         São Paulo
# 3                   Aéreo            Brasil         São Paulo
# 4                   Aéreo            Brasil         São Paulo
# ...                   ...               ...               ...
# 387668              Aéreo            Brasil  Distrito Federal
# 387669              Aéreo            Brasil         São Paulo
# 387670              Aéreo            Brasil  Distrito Federal
# 387671              Aéreo            Brasil         São Paulo
# 387672              Aéreo            Brasil  Distrito Federal
#
#        Cidade - Origem ida         País - Destino ida  UF - Destino ida  \
# 0                 Brasília  Estados Unidos da América               NaN
# 1                São Paulo                     Suécia               NaN
# 2                São Paulo                     Suécia               NaN
# 3                São Paulo                     Suécia               NaN
# 4                São Paulo                     Suécia               NaN
# ...                    ...                        ...               ...
# 387668            Brasília                     Brasil         São Paulo
# 387669           São Paulo                     Brasil  Distrito Federal
# 387670            Brasília                     Brasil         São Paulo
# 387671           São Paulo                     Brasil  Distrito Federal
# 387672            Brasília                     Brasil         São Paulo
#
#        Cidade - Destino ida        País - Origem volta UF - Origem volta  \
# 0                 Nova York  Estados Unidos da América               NaN
# 1                Gotemburgo                     Suécia               NaN
# 2                Gotemburgo                     Suécia               NaN
# 3                Gotemburgo                     Suécia               NaN
# 4                Gotemburgo                     Suécia               NaN
# ...                     ...                        ...               ...
# 387668            São Paulo             Sem informação    Sem informação
# 387669             Brasília             Sem informação    Sem informação
# 387670            São Paulo             Sem informação    Sem informação
# 387671             Brasília             Sem informação    Sem informação
# 387672            São Paulo             Sem informação    Sem informação
#
#        Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# 0                  Nova York               Brasil   Distrito Federal
# 1                 Gotemburgo               Brasil          São Paulo
# 2                 Gotemburgo               Brasil          São Paulo
# 3                 Gotemburgo               Brasil          São Paulo
# 4                 Gotemburgo               Brasil          São Paulo
# ...                      ...                  ...                ...
# 387668        Sem informação       Sem informação     Sem informação
# 387669        Sem informação       Sem informação     Sem informação
# 387670        Sem informação       Sem informação     Sem informação
# 387671        Sem informação       Sem informação     Sem informação
# 387672        Sem informação       Sem informação     Sem informação
#
#        Cidade - Destino volta  Valor da passagem  Taxa de serviço  \
# 0                    Brasília            7434.13             0.00
# 1                   São Paulo            9903.32          4999.78
# 2                   São Paulo            9903.32          4999.78
# 3                   São Paulo            9903.32          4999.78
# 4                   São Paulo            9903.32          4999.78
# ...                       ...                ...              ...
# 387668         Sem informação            2791.41             0.00
# 387669         Sem informação            1764.54             0.00
# 387670         Sem informação            1985.65             0.00
# 387671         Sem informação            1759.88             0.00
# 387672         Sem informação            2961.55             0.00
#
#        Data da emissão/compra Hora da emissão/compra
# 0                  04/11/2022                  11:04
# 1                  15/09/2022                  13:39
# 2                  15/09/2022                  13:42
# 3                  15/09/2022                  13:51
# 4                  15/09/2022                  13:48
# ...                       ...                    ...
# 387668                    NaN                  00:00
# 387669                    NaN                  00:00
# 387670                    NaN                  00:00
# 387671                    NaN                  00:00
# 387672                    NaN                  00:00
#
# [387673 rows x 19 columns]

# %%
df_passagens[df_passagens['Identificador do processo de viagem'] == 19194886]
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 232069                             19194886                 004304/23
# 232070                             19194886                 004304/23
# 232071                             19194886                 004304/23
# 232072                             19194886                 004304/23
# 232073                             19194886                 004304/23
# 232074                             19194886                 004304/23
# 232075                             19194886                 004304/23
#
#        Meio de transporte          País - Origem ida UF - Origem ida  \
# 232069              Aéreo  Estados Unidos da América             NaN
# 232070              Aéreo                  Indonésia             NaN
# 232071              Aéreo  Estados Unidos da América             NaN
# 232072              Aéreo                  Cingapura             NaN
# 232073              Aéreo                  Filipinas             NaN
# 232074              Aéreo                     Brasil       São Paulo
# 232075              Aéreo                    Camboja             NaN
#
#             Cidade - Origem ida         País - Destino ida UF - Destino ida  \
# 232069                Nova York                     Brasil        São Paulo
# 232070                  Jacarta                    Camboja              NaN
# 232071                Nova York                     Brasil        São Paulo
# 232072                Cingapura  Estados Unidos da América              NaN
# 232073  San Juan - Metro Manila                     Brasil        São Paulo
# 232074                São Paulo                  Indonésia              NaN
# 232075               Phnom Penh                  Cingapura              NaN
#
#        Cidade - Destino ida País - Origem volta UF - Origem volta  \
# 232069            São Paulo      Sem informação    Sem informação
# 232070           Phnom Penh      Sem informação    Sem informação
# 232071            São Paulo      Sem informação    Sem informação
# 232072            Nova York      Sem informação    Sem informação
# 232073            São Paulo      Sem informação    Sem informação
# 232074              Jacarta      Sem informação    Sem informação
# 232075            Cingapura      Sem informação    Sem informação
#
#        Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# 232069        Sem informação       Sem informação     Sem informação
# 232070        Sem informação       Sem informação     Sem informação
# 232071        Sem informação       Sem informação     Sem informação
# 232072        Sem informação       Sem informação     Sem informação
# 232073        Sem informação       Sem informação     Sem informação
# 232074        Sem informação       Sem informação     Sem informação
# 232075        Sem informação       Sem informação     Sem informação
#
#        Cidade - Destino volta  Valor da passagem  Taxa de serviço  \
# 232069         Sem informação           35304.33             0.00
# 232070         Sem informação            1667.56             0.00
# 232071         Sem informação           51557.43             0.00
# 232072         Sem informação           42368.61             0.00
# 232073         Sem informação            7926.43             0.00
# 232074         Sem informação           41529.96             0.00
# 232075         Sem informação            6368.97             0.00
#
#        Data da emissão/compra Hora da emissão/compra
# 232069             20/11/2023                  17:47
# 232070             22/08/2023                  14:53
# 232071             17/10/2023                  17:58
# 232072             17/10/2023                  17:57
# 232073             20/09/2023                  11:06
# 232074             22/08/2023                  14:53
# 232075             17/10/2023                  16:33

# %%
df_viagens.merge(df_passagens)
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18288418              000007/23-1C
# 1                                  18302983                 000001/23
# 2                                  18306758                 000002/23
# 3                                  18306785                 000004/23
# 4                                  18306786                 000003/23
# ...                                     ...                       ...
# 387676                           2023001628             Sem informaçã
# 387677                           2023001628             Sem informaçã
# 387678                           2023001631             Sem informaçã
# 387679                           2023001631             Sem informaçã
# 387680                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# 0       Realizada            SIM   Por necessidade do serviço.
# 1       Realizada            NÃO                Sem informação
# 2       Realizada            NÃO                Sem informação
# 3       Realizada            NÃO                Sem informação
# 4       Realizada            NÃO                Sem informação
# ...           ...            ...                           ...
# 387676  Realizada            NÃO                Sem informação
# 387677  Realizada            NÃO                Sem informação
# 387678  Realizada            NÃO                Sem informação
# 387679  Realizada            NÃO                Sem informação
# 387680  Realizada            NÃO                Sem informação
#
#         Código do órgão superior Nome do órgão superior  \
# 0                          52000   Ministério da Defesa
# 1                          52000   Ministério da Defesa
# 2                          52000   Ministério da Defesa
# 3                          52000   Ministério da Defesa
# 4                          52000   Ministério da Defesa
# ...                          ...                    ...
# 387676                        -1         Sem informação
# 387677                        -1         Sem informação
# 387678                        -1         Sem informação
# 387679                        -1         Sem informação
# 387680                        -1         Sem informação
#
#         Código órgão solicitante  Nome órgão solicitante    CPF viajante  \
# 0                          52121     Comando do Exército  ***.621.358-**
# 1                          52111  Comando da Aeronáutica  ***.855.388-**
# 2                          52111  Comando da Aeronáutica  ***.295.391-**
# 3                          52111  Comando da Aeronáutica  ***.221.068-**
# 4                          52111  Comando da Aeronáutica  ***.850.918-**
# ...                          ...                     ...             ...
# 387676                        -1          Sem informação  ***.632.011-**
# 387677                        -1          Sem informação  ***.632.011-**
# 387678                        -1          Sem informação  ***.407.445-**
# 387679                        -1          Sem informação  ***.407.445-**
# 387680                        -1          Sem informação  ***.602.017-**
#
#                                    Nome                        Cargo  \
# 0          ANDRE LUIS COSTA PITANGUEIRA             NÃO IDENTIFICADO
# 1                         GREGOR GASPAR             NÃO IDENTIFICADO
# 2              VITOR LUIS MARTINS FARIA             NÃO IDENTIFICADO
# 3       RAFAEL RODRIGO MANCIN DE MORAIS             NÃO IDENTIFICADO
# 4          BRUNO NOCENTE REGATO PEREIRA             NÃO IDENTIFICADO
# ...                                 ...                          ...
# 387676                   SERGIO BOTELHO     TECNICO DO BANCO CENTRAL
# 387677                   SERGIO BOTELHO     TECNICO DO BANCO CENTRAL
# 387678        NELSON CAMPOS REIS JUNIOR     TECNICO DO BANCO CENTRAL
# 387679        NELSON CAMPOS REIS JUNIOR     TECNICO DO BANCO CENTRAL
# 387680  ROBERTO DE OLIVEIRA CAMPOS NETO  PRESIDENTE DO BANCO CENTRAL
#
#             Função Descrição Função Período - Data de início  \
# 0       OfSuperior       OfSuperior               2023-01-10
# 1       OfIntermed       OfIntermed               2023-01-01
# 2       OfIntermed       OfIntermed               2023-01-01
# 3       OfIntermed       OfIntermed               2023-01-01
# 4       OfIntermed       OfIntermed               2023-01-01
# ...            ...              ...                      ...
# 387676          -1   Sem informação               2023-12-07
# 387677          -1   Sem informação               2023-12-07
# 387678          -1   Sem informação               2023-12-11
# 387679          -1   Sem informação               2023-12-11
# 387680          -1   Sem informação               2023-12-15
#
#        Período - Data de fim                             Destinos  \
# 0                 2023-01-29  Nova York/Estados Unidos da América
# 1                 2023-07-07                    Gotemburgo/Suécia
# 2                 2023-07-07                    Gotemburgo/Suécia
# 3                 2023-07-07                    Gotemburgo/Suécia
# 4                 2023-07-07                    Gotemburgo/Suécia
# ...                      ...                                  ...
# 387676            2023-12-08                       Sem informação
# 387677            2023-12-08                       Sem informação
# 387678            2023-12-11                       Sem informação
# 387679            2023-12-11                       Sem informação
# 387680            2023-12-18                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0       Participar da revisão do COE Manual (Contingen...       39565.70
# 1            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# 2            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# 3            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 387676     Acompanhamento do Presidente do BC - São Paulo         734.13
# 387677     Acompanhamento do Presidente do BC - São Paulo         734.13
# 387678          Acompanhamento do Presidente - São Paulo.         319.28
# 387679          Acompanhamento do Presidente - São Paulo.         319.28
# 387680                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  Despesas  \
# 0               7434.13             0.00              1095.35  48095.18
# 1              14903.10             0.00                 0.00  14903.10
# 2              14903.10             0.00                 0.00  14903.10
# 3              14903.10             0.00                 0.00  14903.10
# 4              14903.10             0.00                 0.00  14903.10
# ...                 ...              ...                  ...       ...
# 387676          4555.95             0.00                 0.00   5290.08
# 387677          4555.95             0.00                 0.00   5290.08
# 387678          3745.53             0.00               400.00   4464.81
# 387679          3745.53             0.00               400.00   4464.81
# 387680          2961.55             0.00                 0.00   2961.55
#
#        Mes da viagem  Dias de viagem Meio de transporte País - Origem ida  \
# 0            January              19              Aéreo            Brasil
# 1            January             187              Aéreo            Brasil
# 2            January             187              Aéreo            Brasil
# 3            January             187              Aéreo            Brasil
# 4            January             187              Aéreo            Brasil
# ...              ...             ...                ...               ...
# 387676      December               1              Aéreo            Brasil
# 387677      December               1              Aéreo            Brasil
# 387678      December               0              Aéreo            Brasil
# 387679      December               0              Aéreo            Brasil
# 387680      December               3              Aéreo            Brasil
#
#          UF - Origem ida Cidade - Origem ida         País - Destino ida  \
# 0       Distrito Federal            Brasília  Estados Unidos da América
# 1              São Paulo           São Paulo                     Suécia
# 2              São Paulo           São Paulo                     Suécia
# 3              São Paulo           São Paulo                     Suécia
# 4              São Paulo           São Paulo                     Suécia
# ...                  ...                 ...                        ...
# 387676  Distrito Federal            Brasília                     Brasil
# 387677         São Paulo           São Paulo                     Brasil
# 387678  Distrito Federal            Brasília                     Brasil
# 387679         São Paulo           São Paulo                     Brasil
# 387680  Distrito Federal            Brasília                     Brasil
#
#         UF - Destino ida Cidade - Destino ida        País - Origem volta  \
# 0                    NaN            Nova York  Estados Unidos da América
# 1                    NaN           Gotemburgo                     Suécia
# 2                    NaN           Gotemburgo                     Suécia
# 3                    NaN           Gotemburgo                     Suécia
# 4                    NaN           Gotemburgo                     Suécia
# ...                  ...                  ...                        ...
# 387676         São Paulo            São Paulo             Sem informação
# 387677  Distrito Federal             Brasília             Sem informação
# 387678         São Paulo            São Paulo             Sem informação
# 387679  Distrito Federal             Brasília             Sem informação
# 387680         São Paulo            São Paulo             Sem informação
#
#        UF - Origem volta Cidade - Origem volta Pais - Destino volta  \
# 0                    NaN             Nova York               Brasil
# 1                    NaN            Gotemburgo               Brasil
# 2                    NaN            Gotemburgo               Brasil
# 3                    NaN            Gotemburgo               Brasil
# 4                    NaN            Gotemburgo               Brasil
# ...                  ...                   ...                  ...
# 387676    Sem informação        Sem informação       Sem informação
# 387677    Sem informação        Sem informação       Sem informação
# 387678    Sem informação        Sem informação       Sem informação
# 387679    Sem informação        Sem informação       Sem informação
# 387680    Sem informação        Sem informação       Sem informação
#
#        UF - Destino volta Cidade - Destino volta  Valor da passagem  \
# 0        Distrito Federal               Brasília            7434.13
# 1               São Paulo              São Paulo            9903.32
# 2               São Paulo              São Paulo            9903.32
# 3               São Paulo              São Paulo            9903.32
# 4               São Paulo              São Paulo            9903.32
# ...                   ...                    ...                ...
# 387676     Sem informação         Sem informação            2791.41
# 387677     Sem informação         Sem informação            1764.54
# 387678     Sem informação         Sem informação            1985.65
# 387679     Sem informação         Sem informação            1759.88
# 387680     Sem informação         Sem informação            2961.55
#
#         Taxa de serviço Data da emissão/compra Hora da emissão/compra
# 0                  0.00             04/11/2022                  11:04
# 1               4999.78             15/09/2022                  13:39
# 2               4999.78             15/09/2022                  13:42
# 3               4999.78             15/09/2022                  13:51
# 4               4999.78             15/09/2022                  13:48
# ...                 ...                    ...                    ...
# 387676             0.00                    NaN                  00:00
# 387677             0.00                    NaN                  00:00
# 387678             0.00                    NaN                  00:00
# 387679             0.00                    NaN                  00:00
# 387680             0.00                    NaN                  00:00
#
# [387681 rows x 42 columns]

# %%
caminho_saida = '/content/drive/MyDrive/Asimov_CursoPythonPandas/output/tabela.xlsx'

# %%
df_final.to_excel(caminho_saida, index=False)

# %%
import matplotlib.pyplot as plt

caminho_figura = '/content/drive/MyDrive/Asimov_CursoPythonPandas/output/figura.png'

fig, ax = plt.subplots(figsize=(16, 6))

ax.barh(df_final['Cargo'], df_final['n_viagens'], color='#49deac')
ax.invert_yaxis()
ax.set_facecolor('#3b3b47')

fig.suptitle('Viagens por cargo público (2023)')

plt.figtext(0.65, 0.89,'Fonte: Portal da Transparência', fontsize=8)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize=8)
plt.xlabel('Número de viagens')

plt.savefig(caminho_figura, bbox_inches='tight')
